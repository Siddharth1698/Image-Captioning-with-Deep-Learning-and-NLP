# %% [markdown]
# Given an image like the example below, our goal is to generate a caption such as "a surfer riding on a wave".
#
# ![Man Surfing](https://tensorflow.org/images/surf.jpg)
#
# *[Image Source](https://commons.wikimedia.org/wiki/Surfing#/media/File:Surfing_in_Hawaii.jpg); License: Public Domain*
#
# To accomplish this, you'll use an attention-based model, which enables us to see what parts of the image the model focuses on as it generates a caption.
#
# ![Prediction](https://tensorflow.org/images/imcap_prediction.png)
#
# The model architecture is similar to [Show, Attend and Tell: Neural Image Caption Generation with Visual Attention](https://arxiv.org/abs/1502.03044).
#
# This notebook is an end-to-end example. When you run the notebook, it downloads the [MS-COCO](http://cocodataset.org/#home) dataset, preprocesses and caches a subset of images using Inception V3, trains an encoder-decoder model, and generates captions on new images using the trained model.
#
# In this example, you will train a model on a relatively small amount of data—the first 30,000 captions  for about 20,000 images (because there are multiple captions per image in the dataset).

# %%
import tensorflow as tf

# You'll generate plots of attention in order to see which parts of an image
# our model focuses on during captioning
import matplotlib.pyplot as plt

import collections
import random
import numpy as np
import os
import time
import json
from PIL import Image

# %% [markdown]
# ## Download and prepare the MS-COCO dataset
#
# You will use the [MS-COCO dataset](http://cocodataset.org/#home) to train our model. The dataset contains over 82,000 images, each of which has at least 5 different caption annotations. The code below downloads and extracts the dataset automatically.
#
# **Caution: large download ahead**. You'll use the training set, which is a 13GB file.

# %%
# Download caption annotation files
annotation_folder = '/annotations/'
if not os.path.exists(os.path.abspath('.') + annotation_folder):
  annotation_zip = tf.keras.utils.get_file('captions.zip',
                                           cache_subdir=os.path.abspath('.'),
                                           origin='http://images.cocodataset.org/annotations/annotations_trainval2014.zip',
                                           extract=True)
  annotation_file = os.path.dirname(annotation_zip)+'/annotations/captions_train2014.json'
  os.remove(annotation_zip)

# Download image files
image_folder = '/train2014/'
if not os.path.exists(os.path.abspath('.') + image_folder):
  image_zip = tf.keras.utils.get_file('train2014.zip',
                                      cache_subdir=os.path.abspath('.'),
                                      origin='http://images.cocodataset.org/zips/train2014.zip',
                                      extract=True)
  PATH = os.path.dirname(image_zip) + image_folder
  os.remove(image_zip)
else:
  PATH = os.path.abspath('.') + image_folder
# Out:
# Downloading data from http://images.cocodataset.org/zips/train2014.zip
# 13510574080/13510573713 [==============================] - 219s 0us/step

# %% [markdown]
# ## Optional: limit the size of the training set
# To speed up training for this tutorial, you'll use a subset of 30,000 captions and their corresponding images to train our model. Choosing to use more data would result in improved captioning quality.

# %%
with open(annotation_file, 'r') as f:
    annotations = json.load(f)

# %%
# Group all captions together having the same image ID.
image_path_to_caption = collections.defaultdict(list)
for val in annotations['annotations']:
  caption = f"<start> {val['caption']} <end>"
  image_path = PATH + 'COCO_train2014_' + '%012d.jpg' % (val['image_id'])
  image_path_to_caption[image_path].append(caption)

# %%
image_paths = list(image_path_to_caption.keys())
random.shuffle(image_paths)

# Select the first 6000 image_paths from the shuffled set.
# Approximately each image id has 5 captions associated with it, so that will
# lead to 30,000 examples.
train_image_paths = image_paths[:6000]
print(len(train_image_paths))
# Out:
# 6000

# %%
train_captions = []
img_name_vector = []

for image_path in train_image_paths:
  caption_list = image_path_to_caption[image_path]
  train_captions.extend(caption_list)
  img_name_vector.extend([image_path] * len(caption_list))

# %%
print(train_captions[0])
Image.open(img_name_vector[0])
# Out:
# <start> A woman flying a kite while standing on a beach. <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=426x640 at 0x7F072F9A6890>

# %%
import pickle

with open('/content/list_1.ob', 'wb') as fp:
    pickle.dump(train_captions, fp)

# %% [markdown]
# ## Preprocess the images using InceptionV3
# Next, you will use InceptionV3 (which is pretrained on Imagenet) to classify each image. You will extract features from the last convolutional layer.
#
# First, you will convert the images into InceptionV3's expected format by:
# * Resizing the image to 299px by 299px
# * [Preprocess the images](https://cloud.google.com/tpu/docs/inception-v3-advanced#preprocessing_stage) using the [preprocess_input](https://www.tensorflow.org/api_docs/python/tf/keras/applications/inception_v3/preprocess_input) method to normalize the image so that it contains pixels in the range of -1 to 1, which matches the format of the images used to train InceptionV3.

# %%
def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (299, 299))
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img, image_path

# %% [markdown]
# ## Initialize InceptionV3 and load the pretrained Imagenet weights
#
# Now you'll create a tf.keras model where the output layer is the last convolutional layer in the InceptionV3 architecture. The shape of the output of this layer is ```8x8x2048```. You use the last convolutional layer because you are using attention in this example. You don't perform this initialization during training because it could become a bottleneck.
#
# * You forward each image through the network and store the resulting vector in a dictionary (image_name --> feature_vector).
# * After all the images are passed through the network, you save the dictionary to disk.

# %%
image_model = tf.keras.applications.InceptionV3(include_top=False,
                                                weights='imagenet')
new_input = image_model.input
hidden_layer = image_model.layers[-1].output

image_features_extract_model = tf.keras.Model(new_input, hidden_layer)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step

# %% [markdown]
# ## Caching the features extracted from InceptionV3
#
# You will pre-process each image with InceptionV3 and cache the output to disk. Caching the output in RAM would be faster but also memory intensive, requiring 8 \* 8 \* 2048 floats per image. At the time of writing, this exceeds the memory limitations of Colab (currently 12GB of memory).
#
# Performance could be improved with a more sophisticated caching strategy (for example, by sharding the images to reduce random access disk I/O), but that would require more code.
#
# The caching will take about 10 minutes to run in Colab with a GPU. If you'd like to see a progress bar, you can:
#
# 1. install [tqdm](https://github.com/tqdm/tqdm):
#
#     `!pip install tqdm`
#
# 2. Import tqdm:
#
#     `from tqdm import tqdm`
#
# 3. Change the following line:
#
#     `for img, path in image_dataset:`
#
#     to:
#
#     `for img, path in tqdm(image_dataset):`

# %%
# !pip install tqdm

from tqdm import tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.41.1)

# %%
# Get unique images
encode_train = sorted(set(img_name_vector))

# Feel free to change batch_size according to your system configuration
image_dataset = tf.data.Dataset.from_tensor_slices(encode_train)
image_dataset = image_dataset.map(
  load_image, num_parallel_calls=tf.data.AUTOTUNE).batch(16)

for img, path in tqdm(image_dataset):
  batch_features = image_features_extract_model(img)
  batch_features = tf.reshape(batch_features,
                              (batch_features.shape[0], -1, batch_features.shape[3]))

  for bf, p in zip(batch_features, path):
    path_of_feature = p.numpy().decode("utf-8")
    np.save(path_of_feature, bf.numpy())
# Out:
# 100%|██████████| 375/375 [02:22<00:00,  2.64it/s]

# %% [markdown]
# ## Preprocess and tokenize the captions
#
# * First, you'll tokenize the captions (for example, by splitting on spaces). This gives us a  vocabulary of all of the unique words in the data (for example, "surfing", "football", and so on).
# * Next, you'll limit the vocabulary size to the top 5,000 words (to save memory). You'll replace all other words with the token "UNK" (unknown).
# * You then create word-to-index and index-to-word mappings.
# * Finally, you pad all sequences to be the same length as the longest one.

# %%
# Find the maximum length of any caption in our dataset
def calc_max_length(tensor):
    return max(len(t) for t in tensor)

# %%
# Choose the top 5000 words from the vocabulary
top_k = 5000
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=top_k,
                                                  oov_token="<unk>",
                                                  filters='!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ')
tokenizer.fit_on_texts(train_captions)

# %%
tokenizer.word_index['<pad>'] = 0
tokenizer.index_word[0] = '<pad>'

# %%
# Create the tokenized vectors
train_seqs = tokenizer.texts_to_sequences(train_captions)

# %%
# Pad each vector to the max_length of the captions
# If you do not provide a max_length value, pad_sequences calculates it automatically
cap_vector = tf.keras.preprocessing.sequence.pad_sequences(train_seqs, padding='post')

# %%
# Calculates the max_length, which is used to store the attention weights
max_length = calc_max_length(train_seqs)

# %%
max_length
# Out:
# 52

# %% [markdown]
# ## Split the data into training and testing

# %%
img_to_cap_vector = collections.defaultdict(list)
for img, cap in zip(img_name_vector, cap_vector):
  img_to_cap_vector[img].append(cap)

# Create training and validation sets using an 80-20 split randomly.
img_keys = list(img_to_cap_vector.keys())
random.shuffle(img_keys)

slice_index = int(len(img_keys)*0.8)
img_name_train_keys, img_name_val_keys = img_keys[:slice_index], img_keys[slice_index:]

img_name_train = []
cap_train = []
for imgt in img_name_train_keys:
  capt_len = len(img_to_cap_vector[imgt])
  img_name_train.extend([imgt] * capt_len)
  cap_train.extend(img_to_cap_vector[imgt])

img_name_val = []
cap_val = []
for imgv in img_name_val_keys:
  capv_len = len(img_to_cap_vector[imgv])
  img_name_val.extend([imgv] * capv_len)
  cap_val.extend(img_to_cap_vector[imgv])

# %%
len(img_name_train), len(cap_train), len(img_name_val), len(cap_val)
# Out:
# (24015, 24015, 6006, 6006)

# %% [markdown]
# ## Create a tf.data dataset for training

# %% [markdown]
#  Our images and captions are ready! Next, let's create a tf.data dataset to use for training our model.

# %%
# Feel free to change these parameters according to your system's configuration

BATCH_SIZE = 64
BUFFER_SIZE = 1000
embedding_dim = 256
units = 512
vocab_size = top_k + 1
num_steps = len(img_name_train) // BATCH_SIZE
# Shape of the vector extracted from InceptionV3 is (64, 2048)
# These two variables represent that vector shape
features_shape = 2048
attention_features_shape = 64

# %%
# Load the numpy files
def map_func(img_name, cap):
  img_tensor = np.load(img_name.decode('utf-8')+'.npy')
  return img_tensor, cap

# %%
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

# Use map to load the numpy files in parallel
dataset = dataset.map(lambda item1, item2: tf.numpy_function(
          map_func, [item1, item2], [tf.float32, tf.int32]),
          num_parallel_calls=tf.data.AUTOTUNE)

# Shuffle and batch
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# ## Model
#
# Fun fact: the decoder below is identical to the one in the example for [Neural Machine Translation with Attention](../sequences/nmt_with_attention.ipynb).
#
# The model architecture is inspired by the [Show, Attend and Tell](https://arxiv.org/pdf/1502.03044.pdf) paper.
#
# * In this example, you extract the features from the lower convolutional layer of InceptionV3 giving us a vector of shape (8, 8, 2048).
# * You squash that to a shape of (64, 2048).
# * This vector is then passed through the CNN Encoder (which consists of a single Fully connected layer).
# * The RNN (here GRU) attends over the image to predict the next word.

# %%
class BahdanauAttention(tf.keras.Model):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, features, hidden):
    # features(CNN_encoder output) shape == (batch_size, 64, embedding_dim)

    # hidden shape == (batch_size, hidden_size)
    # hidden_with_time_axis shape == (batch_size, 1, hidden_size)
    hidden_with_time_axis = tf.expand_dims(hidden, 1)

    # attention_hidden_layer shape == (batch_size, 64, units)
    attention_hidden_layer = (tf.nn.tanh(self.W1(features) +
                                         self.W2(hidden_with_time_axis)))

    # score shape == (batch_size, 64, 1)
    # This gives you an unnormalized score for each image feature.
    score = self.V(attention_hidden_layer)

    # attention_weights shape == (batch_size, 64, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * features
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
class CNN_Encoder(tf.keras.Model):
    # Since you have already extracted the features and dumped it
    # This encoder passes those features through a Fully connected layer
    def __init__(self, embedding_dim):
        super(CNN_Encoder, self).__init__()
        # shape after fc == (batch_size, 64, embedding_dim)
        self.fc = tf.keras.layers.Dense(embedding_dim)

    def call(self, x):
        x = self.fc(x)
        x = tf.nn.relu(x)
        return x

# %%
class RNN_Decoder(tf.keras.Model):
  def __init__(self, embedding_dim, units, vocab_size):
    super(RNN_Decoder, self).__init__()
    self.units = units

    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc1 = tf.keras.layers.Dense(self.units)
    self.fc2 = tf.keras.layers.Dense(vocab_size)

    self.attention = BahdanauAttention(self.units)

  def call(self, x, features, hidden):
    # defining attention as a separate model
    context_vector, attention_weights = self.attention(features, hidden)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x)

    # shape == (batch_size, max_length, hidden_size)
    x = self.fc1(output)

    # x shape == (batch_size * max_length, hidden_size)
    x = tf.reshape(x, (-1, x.shape[2]))

    # output shape == (batch_size * max_length, vocab)
    x = self.fc2(x)

    return x, state, attention_weights

  def reset_state(self, batch_size):
    return tf.zeros((batch_size, self.units))

# %%
encoder = CNN_Encoder(embedding_dim)
decoder = RNN_Decoder(embedding_dim, units, vocab_size)

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')


def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %% [markdown]
# ## Checkpoint

# %%
checkpoint_path = "./checkpoints/train"
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer=optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
  start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])
  # restoring the latest checkpoint in checkpoint_path
  ckpt.restore(ckpt_manager.latest_checkpoint)

# %% [markdown]
# ## Training
#
# * You extract the features stored in the respective `.npy` files and then pass those features through the encoder.
# * The encoder output, hidden state(initialized to 0) and the decoder input (which is the start token) is passed to the decoder.
# * The decoder returns the predictions and the decoder hidden state.
# * The decoder hidden state is then passed back into the model and the predictions are used to calculate the loss.
# * Use teacher forcing to decide the next input to the decoder.
# * Teacher forcing is the technique where the target word is passed as the next input to the decoder.
# * The final step is to calculate the gradients and apply it to the optimizer and backpropagate.

# %%
# adding this in a separate cell because if you run the training cell
# many times, the loss_plot array will be reset
loss_plot = []

# %%
@tf.function
def train_step(img_tensor, target):
  loss = 0

  # initializing the hidden state for each batch
  # because the captions are not related from image to image
  hidden = decoder.reset_state(batch_size=target.shape[0])

  dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * target.shape[0], 1)

  with tf.GradientTape() as tape:
      features = encoder(img_tensor)

      for i in range(1, target.shape[1]):
          # passing the features through the decoder
          predictions, hidden, _ = decoder(dec_input, features, hidden)

          loss += loss_function(target[:, i], predictions)

          # using teacher forcing
          dec_input = tf.expand_dims(target[:, i], 1)

  total_loss = (loss / int(target.shape[1]))

  trainable_variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, trainable_variables)

  optimizer.apply_gradients(zip(gradients, trainable_variables))

  return loss, total_loss

# %%
EPOCHS = 100

for epoch in range(start_epoch, EPOCHS):
    start = time.time()
    total_loss = 0

    for (batch, (img_tensor, target)) in enumerate(dataset):
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss

        if batch % 100 == 0:
            average_batch_loss = batch_loss.numpy()/int(target.shape[1])
            print(f'Epoch {epoch+1} Batch {batch} Loss {average_batch_loss:.4f}')
    # storing the epoch end loss value to plot later
    loss_plot.append(total_loss / num_steps)

    if epoch % 5 == 0:
      ckpt_manager.save() 

    print(f'Epoch {epoch+1} Loss {total_loss/num_steps:.6f}')
    print(f'Time taken for 1 epoch {time.time()-start:.2f} sec\n')
# Out:
# Epoch 1 Batch 0 Loss 0.4339
# Epoch 1 Batch 100 Loss 0.4115
# Epoch 1 Batch 200 Loss 0.4326
# Epoch 1 Batch 300 Loss 0.3855
# Epoch 1 Loss 0.417999
# Time taken for 1 epoch 72.63 sec
#
# Epoch 2 Batch 0 Loss 0.4123
# Epoch 2 Batch 100 Loss 0.3429
# Epoch 2 Batch 200 Loss 0.3861
# Epoch 2 Batch 300 Loss 0.3524
# Epoch 2 Loss 0.395750
# Time taken for 1 epoch 72.33 sec
#
# Epoch 3 Batch 0 Loss 0.3703
# Epoch 3 Batch 100 Loss 0.3717
# Epoch 3 Batch 200 Loss 0.3472
# Epoch 3 Batch 300 Loss 0.3442
# Epoch 3 Loss 0.376528
# Time taken for 1 epoch 71.35 sec
#
# Epoch 4 Batch 0 Loss 0.4034
# Epoch 4 Batch 100 Loss 0.3360
# Epoch 4 Batch 200 Loss 0.3544
# Epoch 4 Batch 300 Loss 0.3262
# Epoch 4 Loss 0.356702
# Time taken for 1 epoch 71.75 sec
#
# Epoch 5 Batch 0 Loss 0.3435
# Epoch 5 Batch 100 Loss 0.3144
# Epoch 5 Batch 200 Loss 0.3882
# Epoch 5 Batch 300 Loss 0.3365
# Epoch 5 Loss 0.338328
# Time taken for 1 epoch 71.82 sec
#
# Epoch 6 Batch 0 Loss 0.3692
# Epoch 6 Batch 100 Loss 0.2950
# Epoch 6 Batch 200 Loss 0.3080
# Epoch 6 Batch 300 Loss 0.3192
# Epoch 6 Loss 0.323052
# Time taken for 1 epoch 71.83 sec
#
# Epoch 7 Batch 0 Loss 0.3233
# Epoch 7 Batch 100 Loss 0.3050
# Epoch 7 Batch 200 Loss 0.3180
# Epoch 7 Batch 300 Loss 0.3044
# Epoch 7 Loss 0.306218
# Time taken for 1 epoch 71.16 sec
#
# Epoch 8 Batch 0 Loss 0.3218
# Epoch 8 Batch 100 Loss 0.2871
# Epoch 8 Batch 200 Loss 0.2699
# Epoch 8 Batch 300 Loss 0.2645
# Epoch 8 Loss 0.292303
# Time taken for 1 epoch 71.06 sec
#
# Epoch 9 Batch 0 Loss 0.2865
# Epoch 9 Batch 100 Loss 0.2549
# Epoch 9 Batch 200 Loss 0.2891
# Epoch 9 Batch 300 Loss 0.2680
# Epoch 9 Loss 0.278726
# Time taken for 1 epoch 71.46 sec
#
# Epoch 10 Batch 0 Loss 0.2665
# Epoch 10 Batch 100 Loss 0.2735
# Epoch 10 Batch 200 Loss 0.2880
# Epoch 10 Batch 300 Loss 0.2609
# Epoch 10 Loss 0.265901
# Time taken for 1 epoch 71.95 sec
#
# Epoch 11 Batch 0 Loss 0.2726
# Epoch 11 Batch 100 Loss 0.2625
# Epoch 11 Batch 200 Loss 0.2217
# Epoch 11 Batch 300 Loss 0.2525
# Epoch 11 Loss 0.256072
# Time taken for 1 epoch 71.88 sec
#
# Epoch 12 Batch 0 Loss 0.2797
# Epoch 12 Batch 100 Loss 0.2500
# Epoch 12 Batch 200 Loss 0.2304
# Epoch 12 Batch 300 Loss 0.2459
# Epoch 12 Loss 0.245180
# Time taken for 1 epoch 71.81 sec
#
# Epoch 13 Batch 0 Loss 0.2690
# Epoch 13 Batch 100 Loss 0.2253
# Epoch 13 Batch 200 Loss 0.2318
# Epoch 13 Batch 300 Loss 0.2368
# Epoch 13 Loss 0.235331
# Time taken for 1 epoch 71.09 sec
#
# Epoch 14 Batch 0 Loss 0.2617
# Epoch 14 Batch 100 Loss 0.1960
# Epoch 14 Batch 200 Loss 0.2278
# Epoch 14 Batch 300 Loss 0.2221
# Epoch 14 Loss 0.225055
# Time taken for 1 epoch 71.22 sec
#
# Epoch 15 Batch 0 Loss 0.2248
# Epoch 15 Batch 100 Loss 0.2174
# Epoch 15 Batch 200 Loss 0.2150
# Epoch 15 Batch 300 Loss 0.2146
# Epoch 15 Loss 0.216826
# Time taken for 1 epoch 71.02 sec
#
# Epoch 16 Batch 0 Loss 0.2031
# Epoch 16 Batch 100 Loss 0.2129
# Epoch 16 Batch 200 Loss 0.2105
# Epoch 16 Batch 300 Loss 0.2110
# Epoch 16 Loss 0.209480
# Time taken for 1 epoch 71.51 sec
#
# Epoch 17 Batch 0 Loss 0.2317
# Epoch 17 Batch 100 Loss 0.2200
# Epoch 17 Batch 200 Loss 0.1979
# Epoch 17 Batch 300 Loss 0.2094
# Epoch 17 Loss 0.202488
# Time taken for 1 epoch 71.41 sec
#
# Epoch 18 Batch 0 Loss 0.2028
# Epoch 18 Batch 100 Loss 0.1845
# Epoch 18 Batch 200 Loss 0.2010
# Epoch 18 Batch 300 Loss 0.1959
# Epoch 18 Loss 0.197005
# Time taken for 1 epoch 71.82 sec
#
# Epoch 19 Batch 0 Loss 0.1789
# Epoch 19 Batch 100 Loss 0.2045
# Epoch 19 Batch 200 Loss 0.1772
# Epoch 19 Batch 300 Loss 0.1934
# Epoch 19 Loss 0.190358
# Time taken for 1 epoch 71.87 sec
#
# Epoch 20 Batch 0 Loss 0.2095
# Epoch 20 Batch 100 Loss 0.1786
# Epoch 20 Batch 200 Loss 0.1817
# Epoch 20 Batch 300 Loss 0.1765
# Epoch 20 Loss 0.184776
# Time taken for 1 epoch 71.73 sec
#
# Epoch 21 Batch 0 Loss 0.1847
# Epoch 21 Batch 100 Loss 0.1679
# Epoch 21 Batch 200 Loss 0.1591
# Epoch 21 Batch 300 Loss 0.1650
# Epoch 21 Loss 0.180369
# Time taken for 1 epoch 72.29 sec
#
# Epoch 22 Batch 0 Loss 0.1858
# Epoch 22 Batch 100 Loss 0.1710
# Epoch 22 Batch 200 Loss 0.1881
# Epoch 22 Batch 300 Loss 0.1790
# Epoch 22 Loss 0.176026
# Time taken for 1 epoch 71.78 sec
#
# Epoch 23 Batch 0 Loss 0.1925
# Epoch 23 Batch 100 Loss 0.1624
# Epoch 23 Batch 200 Loss 0.1661
# Epoch 23 Batch 300 Loss 0.1811
# Epoch 23 Loss 0.173256
# Time taken for 1 epoch 72.14 sec
#
# Epoch 24 Batch 0 Loss 0.1804
# Epoch 24 Batch 100 Loss 0.1845
# Epoch 24 Batch 200 Loss 0.1626
# Epoch 24 Batch 300 Loss 0.1506
# Epoch 24 Loss 0.169420
# Time taken for 1 epoch 71.63 sec
#
# Epoch 25 Batch 0 Loss 0.1973
# Epoch 25 Batch 100 Loss 0.1547
# Epoch 25 Batch 200 Loss 0.1615
# Epoch 25 Batch 300 Loss 0.1666
# Epoch 25 Loss 0.165421
# Time taken for 1 epoch 71.65 sec
#
# Epoch 26 Batch 0 Loss 0.1699
# Epoch 26 Batch 100 Loss 0.1545
# Epoch 26 Batch 200 Loss 0.1636
# Epoch 26 Batch 300 Loss 0.1583
# Epoch 26 Loss 0.159545
# Time taken for 1 epoch 71.83 sec
#
# Epoch 27 Batch 0 Loss 0.1706
# Epoch 27 Batch 100 Loss 0.1495
# Epoch 27 Batch 200 Loss 0.1534
# Epoch 27 Batch 300 Loss 0.1399
# Epoch 27 Loss 0.157333
# Time taken for 1 epoch 72.08 sec
#
# Epoch 28 Batch 0 Loss 0.1517
# Epoch 28 Batch 100 Loss 0.1573
# Epoch 28 Batch 200 Loss 0.1582
# Epoch 28 Batch 300 Loss 0.1489
# Epoch 28 Loss 0.155672
# Time taken for 1 epoch 72.34 sec
#
# Epoch 29 Batch 0 Loss 0.1377
# Epoch 29 Batch 100 Loss 0.1543
# Epoch 29 Batch 200 Loss 0.1474
# Epoch 29 Batch 300 Loss 0.1624
# Epoch 29 Loss 0.153591
# Time taken for 1 epoch 71.79 sec
#
# Epoch 30 Batch 0 Loss 0.1416
# Epoch 30 Batch 100 Loss 0.1535
# Epoch 30 Batch 200 Loss 0.1512
# Epoch 30 Batch 300 Loss 0.1444
# Epoch 30 Loss 0.152450
# Time taken for 1 epoch 71.78 sec
#
# Epoch 31 Batch 0 Loss 0.1805
# Epoch 31 Batch 100 Loss 0.1579
# Epoch 31 Batch 200 Loss 0.1469
# Epoch 31 Batch 300 Loss 0.1522
# Epoch 31 Loss 0.151319
# Time taken for 1 epoch 72.25 sec
#
# Epoch 32 Batch 0 Loss 0.1442
# Epoch 32 Batch 100 Loss 0.1409
# Epoch 32 Batch 200 Loss 0.1692
# Epoch 32 Batch 300 Loss 0.1536
# Epoch 32 Loss 0.144973
# Time taken for 1 epoch 71.93 sec
#
# Epoch 33 Batch 0 Loss 0.1486
# Epoch 33 Batch 100 Loss 0.1349
# Epoch 33 Batch 200 Loss 0.1470
# Epoch 33 Batch 300 Loss 0.1356
# Epoch 33 Loss 0.142715
# Time taken for 1 epoch 71.68 sec
#
# Epoch 34 Batch 0 Loss 0.1636
# Epoch 34 Batch 100 Loss 0.1491
# Epoch 34 Batch 200 Loss 0.1392
# Epoch 34 Batch 300 Loss 0.1315
# Epoch 34 Loss 0.142049
# Time taken for 1 epoch 72.19 sec
#
# Epoch 35 Batch 0 Loss 0.1338
# Epoch 35 Batch 100 Loss 0.1368
# Epoch 35 Batch 200 Loss 0.1304
# Epoch 35 Batch 300 Loss 0.1476
# Epoch 35 Loss 0.144723
# Time taken for 1 epoch 71.91 sec
#
# Epoch 36 Batch 0 Loss 0.1256
# Epoch 36 Batch 100 Loss 0.1338
# Epoch 36 Batch 200 Loss 0.1244
# Epoch 36 Batch 300 Loss 0.1257
# Epoch 36 Loss 0.137104
# Time taken for 1 epoch 72.14 sec
#
# Epoch 37 Batch 0 Loss 0.1142
# Epoch 37 Batch 100 Loss 0.1584
# Epoch 37 Batch 200 Loss 0.1319
# Epoch 37 Batch 300 Loss 0.1511
# Epoch 37 Loss 0.135047
# Time taken for 1 epoch 71.47 sec
#
# Epoch 38 Batch 0 Loss 0.1256
# Epoch 38 Batch 100 Loss 0.1395
# Epoch 38 Batch 200 Loss 0.1361
# Epoch 38 Batch 300 Loss 0.1338
# Epoch 38 Loss 0.135134
# Time taken for 1 epoch 71.77 sec
#
# Epoch 39 Batch 0 Loss 0.1369
# Epoch 39 Batch 100 Loss 0.1307
# Epoch 39 Batch 200 Loss 0.1427
# Epoch 39 Batch 300 Loss 0.1265
# Epoch 39 Loss 0.134686
# Time taken for 1 epoch 71.83 sec
#
# Epoch 40 Batch 0 Loss 0.1276
# Epoch 40 Batch 100 Loss 0.1452
# Epoch 40 Batch 200 Loss 0.1275
# Epoch 40 Batch 300 Loss 0.1241
# Epoch 40 Loss 0.132876
# Time taken for 1 epoch 71.65 sec
#
# Epoch 41 Batch 0 Loss 0.1320
# Epoch 41 Batch 100 Loss 0.1365
# Epoch 41 Batch 200 Loss 0.1298
# Epoch 41 Batch 300 Loss 0.1274
# Epoch 41 Loss 0.131050
# Time taken for 1 epoch 72.14 sec
#
# Epoch 42 Batch 0 Loss 0.1278
# Epoch 42 Batch 100 Loss 0.1269
# Epoch 42 Batch 200 Loss 0.1516
# Epoch 42 Batch 300 Loss 0.1254
# Epoch 42 Loss 0.129781
# Time taken for 1 epoch 71.62 sec
#
# Epoch 43 Batch 0 Loss 0.1117
# Epoch 43 Batch 100 Loss 0.1227
# Epoch 43 Batch 200 Loss 0.1104
# Epoch 43 Batch 300 Loss 0.1380
# Epoch 43 Loss 0.129474
# Time taken for 1 epoch 71.40 sec
#
# Epoch 44 Batch 0 Loss 0.1236
# Epoch 44 Batch 100 Loss 0.1315
# Epoch 44 Batch 200 Loss 0.1335
# Epoch 44 Batch 300 Loss 0.1274
# Epoch 44 Loss 0.129387
# Time taken for 1 epoch 71.48 sec
#
# Epoch 45 Batch 0 Loss 0.1178
# Epoch 45 Batch 100 Loss 0.1123
# Epoch 45 Batch 200 Loss 0.1284
# Epoch 45 Batch 300 Loss 0.1234
# Epoch 45 Loss 0.128702
# Time taken for 1 epoch 71.59 sec
#
# Epoch 46 Batch 0 Loss 0.1186
# Epoch 46 Batch 100 Loss 0.1407
# Epoch 46 Batch 200 Loss 0.1176
# Epoch 46 Batch 300 Loss 0.1217
# Epoch 46 Loss 0.127947
# Time taken for 1 epoch 71.91 sec
#
# Epoch 47 Batch 0 Loss 0.1261
# Epoch 47 Batch 100 Loss 0.1276
# Epoch 47 Batch 200 Loss 0.1303
# Epoch 47 Batch 300 Loss 0.1209
# Epoch 47 Loss 0.126446
# Time taken for 1 epoch 71.38 sec
#
# Epoch 48 Batch 0 Loss 0.1336
# Epoch 48 Batch 100 Loss 0.1360
# Epoch 48 Batch 200 Loss 0.1250
# Epoch 48 Batch 300 Loss 0.1179
# Epoch 48 Loss 0.126513
# Time taken for 1 epoch 71.75 sec
#
# Epoch 49 Batch 0 Loss 0.1229
# Epoch 49 Batch 100 Loss 0.1224
# Epoch 49 Batch 200 Loss 0.1198
# Epoch 49 Batch 300 Loss 0.1335
# Epoch 49 Loss 0.123979
# Time taken for 1 epoch 71.69 sec
#
# Epoch 50 Batch 0 Loss 0.1223
# Epoch 50 Batch 100 Loss 0.1122
# Epoch 50 Batch 200 Loss 0.1281
# Epoch 50 Batch 300 Loss 0.1134
# Epoch 50 Loss 0.121734
# Time taken for 1 epoch 71.10 sec
#
# Epoch 51 Batch 0 Loss 0.1090
# Epoch 51 Batch 100 Loss 0.1164
# Epoch 51 Batch 200 Loss 0.1177
# Epoch 51 Batch 300 Loss 0.1242
# Epoch 51 Loss 0.120186
# Time taken for 1 epoch 71.82 sec
#
# Epoch 52 Batch 0 Loss 0.1093
# Epoch 52 Batch 100 Loss 0.1148
# Epoch 52 Batch 200 Loss 0.1325
# Epoch 52 Batch 300 Loss 0.1246
# Epoch 52 Loss 0.120657
# Time taken for 1 epoch 71.86 sec
#
# Epoch 53 Batch 0 Loss 0.1147
# Epoch 53 Batch 100 Loss 0.1200
# Epoch 53 Batch 200 Loss 0.1227
# Epoch 53 Batch 300 Loss 0.1388
# Epoch 53 Loss 0.124242
# Time taken for 1 epoch 71.69 sec
#
# Epoch 54 Batch 0 Loss 0.1415
# Epoch 54 Batch 100 Loss 0.1141
# Epoch 54 Batch 200 Loss 0.1172
# Epoch 54 Batch 300 Loss 0.1138
# Epoch 54 Loss 0.123084
# Time taken for 1 epoch 71.87 sec
#
# Epoch 55 Batch 0 Loss 0.1082
# Epoch 55 Batch 100 Loss 0.1152
# Epoch 55 Batch 200 Loss 0.1333
# Epoch 55 Batch 300 Loss 0.1040
# Epoch 55 Loss 0.121610
# Time taken for 1 epoch 71.89 sec
#
# Epoch 56 Batch 0 Loss 0.1115
# Epoch 56 Batch 100 Loss 0.1161
# Epoch 56 Batch 200 Loss 0.1361
# Epoch 56 Batch 300 Loss 0.1316
# Epoch 56 Loss 0.123967
# Time taken for 1 epoch 72.16 sec
#
# Epoch 57 Batch 0 Loss 0.1197
# Epoch 57 Batch 100 Loss 0.1248
# Epoch 57 Batch 200 Loss 0.1067
# Epoch 57 Batch 300 Loss 0.1033
# Epoch 57 Loss 0.121078
# Time taken for 1 epoch 71.73 sec
#
# Epoch 58 Batch 0 Loss 0.1184
# Epoch 58 Batch 100 Loss 0.1151
# Epoch 58 Batch 200 Loss 0.1123
# Epoch 58 Batch 300 Loss 0.0991
# Epoch 58 Loss 0.116160
# Time taken for 1 epoch 71.50 sec
#
# Epoch 59 Batch 0 Loss 0.0990
# Epoch 59 Batch 100 Loss 0.1123
# Epoch 59 Batch 200 Loss 0.1254
# Epoch 59 Batch 300 Loss 0.1118
# Epoch 59 Loss 0.114179
# Time taken for 1 epoch 71.99 sec
#
# Epoch 60 Batch 0 Loss 0.1034
# Epoch 60 Batch 100 Loss 0.1249
# Epoch 60 Batch 200 Loss 0.1142
# Epoch 60 Batch 300 Loss 0.1117
# Epoch 60 Loss 0.113439
# Time taken for 1 epoch 71.77 sec
#
# Epoch 61 Batch 0 Loss 0.1065
# Epoch 61 Batch 100 Loss 0.0976
# Epoch 61 Batch 200 Loss 0.1107
# Epoch 61 Batch 300 Loss 0.1087
# Epoch 61 Loss 0.114741
# Time taken for 1 epoch 71.97 sec
#
# Epoch 62 Batch 0 Loss 0.1070
# Epoch 62 Batch 100 Loss 0.1190
# Epoch 62 Batch 200 Loss 0.1099
# Epoch 62 Batch 300 Loss 0.1063
# Epoch 62 Loss 0.114509
# Time taken for 1 epoch 71.63 sec
#
# Epoch 63 Batch 0 Loss 0.1088
# Epoch 63 Batch 100 Loss 0.1090
# Epoch 63 Batch 200 Loss 0.1048
# Epoch 63 Batch 300 Loss 0.1219
# Epoch 63 Loss 0.112054
# Time taken for 1 epoch 71.36 sec
#
# Epoch 64 Batch 0 Loss 0.1025
# Epoch 64 Batch 100 Loss 0.1069
# Epoch 64 Batch 200 Loss 0.1058
# Epoch 64 Batch 300 Loss 0.1200
# Epoch 64 Loss 0.113888
# Time taken for 1 epoch 71.51 sec
#
# Epoch 65 Batch 0 Loss 0.1157
# Epoch 65 Batch 100 Loss 0.1109
# Epoch 65 Batch 200 Loss 0.1162
# Epoch 65 Batch 300 Loss 0.0995
# Epoch 65 Loss 0.116288
# Time taken for 1 epoch 71.66 sec
#
# Epoch 66 Batch 0 Loss 0.1075
# Epoch 66 Batch 100 Loss 0.1113
# Epoch 66 Batch 200 Loss 0.1143
# Epoch 66 Batch 300 Loss 0.1189
# Epoch 66 Loss 0.115015
# Time taken for 1 epoch 71.76 sec
#
# Epoch 67 Batch 0 Loss 0.1142
# Epoch 67 Batch 100 Loss 0.1237
# Epoch 67 Batch 200 Loss 0.1229
# Epoch 67 Batch 300 Loss 0.1163
# Epoch 67 Loss 0.116108
# Time taken for 1 epoch 71.73 sec
#
# Epoch 68 Batch 0 Loss 0.1114
# Epoch 68 Batch 100 Loss 0.1024
# Epoch 68 Batch 200 Loss 0.1168
# Epoch 68 Batch 300 Loss 0.1122
# Epoch 68 Loss 0.114813
# Time taken for 1 epoch 71.84 sec
#
# Epoch 69 Batch 0 Loss 0.1028
# Epoch 69 Batch 100 Loss 0.1114
# Epoch 69 Batch 200 Loss 0.1090
# Epoch 69 Batch 300 Loss 0.1049
# Epoch 69 Loss 0.113492
# Time taken for 1 epoch 71.66 sec
#
# Epoch 70 Batch 0 Loss 0.1092
# Epoch 70 Batch 100 Loss 0.1206
# Epoch 70 Batch 200 Loss 0.1070
# Epoch 70 Batch 300 Loss 0.1168
# Epoch 70 Loss 0.113061
# Time taken for 1 epoch 71.14 sec
#
# Epoch 71 Batch 0 Loss 0.1003
# Epoch 71 Batch 100 Loss 0.0961
# Epoch 71 Batch 200 Loss 0.1178
# Epoch 71 Batch 300 Loss 0.1009
# Epoch 71 Loss 0.109939
# Time taken for 1 epoch 71.47 sec
#
# Epoch 72 Batch 0 Loss 0.1045
# Epoch 72 Batch 100 Loss 0.1092
# Epoch 72 Batch 200 Loss 0.1068
# Epoch 72 Batch 300 Loss 0.1104
# Epoch 72 Loss 0.107854
# Time taken for 1 epoch 71.08 sec
#
# Epoch 73 Batch 0 Loss 0.1129
# Epoch 73 Batch 100 Loss 0.1113
# Epoch 73 Batch 200 Loss 0.1119
# Epoch 73 Batch 300 Loss 0.1365
# Epoch 73 Loss 0.115063
# Time taken for 1 epoch 71.73 sec
#
# Epoch 74 Batch 0 Loss 0.1161
# Epoch 74 Batch 100 Loss 0.1051
# Epoch 74 Batch 200 Loss 0.0967
# Epoch 74 Batch 300 Loss 0.1075
# Epoch 74 Loss 0.111765
# Time taken for 1 epoch 71.72 sec
#
# Epoch 75 Batch 0 Loss 0.0995
# Epoch 75 Batch 100 Loss 0.1120
# Epoch 75 Batch 200 Loss 0.0996
# Epoch 75 Batch 300 Loss 0.1237
# Epoch 75 Loss 0.108175
# Time taken for 1 epoch 71.69 sec
#
# Epoch 76 Batch 0 Loss 0.1077
# Epoch 76 Batch 100 Loss 0.1061
# Epoch 76 Batch 200 Loss 0.1055
# Epoch 76 Batch 300 Loss 0.1164
# Epoch 76 Loss 0.107923
# Time taken for 1 epoch 72.08 sec
#
# Epoch 77 Batch 0 Loss 0.0886
# Epoch 77 Batch 100 Loss 0.1133
# Epoch 77 Batch 200 Loss 0.1088
# Epoch 77 Batch 300 Loss 0.1096
# Epoch 77 Loss 0.107518
# Time taken for 1 epoch 71.90 sec
#
# Epoch 78 Batch 0 Loss 0.1043
# Epoch 78 Batch 100 Loss 0.1074
# Epoch 78 Batch 200 Loss 0.1067
# Epoch 78 Batch 300 Loss 0.1018
# Epoch 78 Loss 0.108142
# Time taken for 1 epoch 71.82 sec
#
# Epoch 79 Batch 0 Loss 0.1090
# Epoch 79 Batch 100 Loss 0.1220
# Epoch 79 Batch 200 Loss 0.1262
# Epoch 79 Batch 300 Loss 0.1110
# Epoch 79 Loss 0.107740
# Time taken for 1 epoch 71.71 sec
#
# Epoch 80 Batch 0 Loss 0.1001
# Epoch 80 Batch 100 Loss 0.1212
# Epoch 80 Batch 200 Loss 0.1025
# Epoch 80 Batch 300 Loss 0.0965
# Epoch 80 Loss 0.107608
# Time taken for 1 epoch 72.08 sec
#
# Epoch 81 Batch 0 Loss 0.0926
# Epoch 81 Batch 100 Loss 0.0972
# Epoch 81 Batch 200 Loss 0.1074
# Epoch 81 Batch 300 Loss 0.1145
# Epoch 81 Loss 0.106825
# Time taken for 1 epoch 72.25 sec
#
# Epoch 82 Batch 0 Loss 0.0939
# Epoch 82 Batch 100 Loss 0.0972
# Epoch 82 Batch 200 Loss 0.1029
# Epoch 82 Batch 300 Loss 0.1143
# Epoch 82 Loss 0.108501
# Time taken for 1 epoch 81.91 sec
#
# Epoch 83 Batch 0 Loss 0.0935
# Epoch 83 Batch 100 Loss 0.0987
# Epoch 83 Batch 200 Loss 0.0977
# Epoch 83 Batch 300 Loss 0.1010
# Epoch 83 Loss 0.106412
# Time taken for 1 epoch 71.95 sec
#
# Epoch 84 Batch 0 Loss 0.0812
# Epoch 84 Batch 100 Loss 0.1006
# Epoch 84 Batch 200 Loss 0.1033
# Epoch 84 Batch 300 Loss 0.1141
# Epoch 84 Loss 0.105575
# Time taken for 1 epoch 72.03 sec
#
# Epoch 85 Batch 0 Loss 0.0847
# Epoch 85 Batch 100 Loss 0.1148
# Epoch 85 Batch 200 Loss 0.1058
# Epoch 85 Batch 300 Loss 0.1115
# Epoch 85 Loss 0.108125
# Time taken for 1 epoch 71.65 sec
#
# Epoch 86 Batch 0 Loss 0.1146
# Epoch 86 Batch 100 Loss 0.1127
# Epoch 86 Batch 200 Loss 0.1127
# Epoch 86 Batch 300 Loss 0.0991
# Epoch 86 Loss 0.106920
# Time taken for 1 epoch 72.03 sec
#
# Epoch 87 Batch 0 Loss 0.0989
# Epoch 87 Batch 100 Loss 0.0973
# Epoch 87 Batch 200 Loss 0.1009
# Epoch 87 Batch 300 Loss 0.1031
# Epoch 87 Loss 0.105192
# Time taken for 1 epoch 71.77 sec
#
# Epoch 88 Batch 0 Loss 0.0953
# Epoch 88 Batch 100 Loss 0.1011
# Epoch 88 Batch 200 Loss 0.1009
# Epoch 88 Batch 300 Loss 0.0937
# Epoch 88 Loss 0.104332
# Time taken for 1 epoch 71.81 sec
#
# Epoch 89 Batch 0 Loss 0.1012
# Epoch 89 Batch 100 Loss 0.0956
# Epoch 89 Batch 200 Loss 0.0894
# Epoch 89 Batch 300 Loss 0.1002
# Epoch 89 Loss 0.103169
# Time taken for 1 epoch 71.68 sec
#
# Epoch 90 Batch 0 Loss 0.0991
# Epoch 90 Batch 100 Loss 0.1071
# Epoch 90 Batch 200 Loss 0.0990
# Epoch 90 Batch 300 Loss 0.1024
# Epoch 90 Loss 0.102609
# Time taken for 1 epoch 71.55 sec
#
# Epoch 91 Batch 0 Loss 0.0898
# Epoch 91 Batch 100 Loss 0.0891
# Epoch 91 Batch 200 Loss 0.1213
# Epoch 91 Batch 300 Loss 0.1146
# Epoch 91 Loss 0.102289
# Time taken for 1 epoch 72.52 sec
#
# Epoch 92 Batch 0 Loss 0.0954
# Epoch 92 Batch 100 Loss 0.1021
# Epoch 92 Batch 200 Loss 0.0924
# Epoch 92 Batch 300 Loss 0.1105
# Epoch 92 Loss 0.104032
# Time taken for 1 epoch 72.49 sec
#
# Epoch 93 Batch 0 Loss 0.0939
# Epoch 93 Batch 100 Loss 0.1124
# Epoch 93 Batch 200 Loss 0.1020
# Epoch 93 Batch 300 Loss 0.0944
# Epoch 93 Loss 0.108844
# Time taken for 1 epoch 71.97 sec
#
# Epoch 94 Batch 0 Loss 0.0887
# Epoch 94 Batch 100 Loss 0.1075
# Epoch 94 Batch 200 Loss 0.0964
# Epoch 94 Batch 300 Loss 0.1031
# Epoch 94 Loss 0.106354
# Time taken for 1 epoch 72.27 sec
#
# Epoch 95 Batch 0 Loss 0.0944
# Epoch 95 Batch 100 Loss 0.1052
# Epoch 95 Batch 200 Loss 0.0977
# Epoch 95 Batch 300 Loss 0.0976
# Epoch 95 Loss 0.102984
# Time taken for 1 epoch 71.99 sec
#
# Epoch 96 Batch 0 Loss 0.1044
# Epoch 96 Batch 100 Loss 0.1064
# Epoch 96 Batch 200 Loss 0.0894
# Epoch 96 Batch 300 Loss 0.1130
# Epoch 96 Loss 0.102841
# Time taken for 1 epoch 72.71 sec
#
# Epoch 97 Batch 0 Loss 0.0895
# Epoch 97 Batch 100 Loss 0.1083
# Epoch 97 Batch 200 Loss 0.1104
# Epoch 97 Batch 300 Loss 0.1023
# Epoch 97 Loss 0.101333
# Time taken for 1 epoch 72.48 sec
#
# Epoch 98 Batch 0 Loss 0.0949
# Epoch 98 Batch 100 Loss 0.0973
# Epoch 98 Batch 200 Loss 0.1032
# Epoch 98 Batch 300 Loss 0.1030
# Epoch 98 Loss 0.102868
# Time taken for 1 epoch 72.00 sec
#
# Epoch 99 Batch 0 Loss 0.0960
# Epoch 99 Batch 100 Loss 0.1105
# Epoch 99 Batch 200 Loss 0.1042
# Epoch 99 Batch 300 Loss 0.1141
# Epoch 99 Loss 0.102364
# Time taken for 1 epoch 72.26 sec
#
# Epoch 100 Batch 0 Loss 0.0963
# Epoch 100 Batch 100 Loss 0.1017
# Epoch 100 Batch 200 Loss 0.0984
# Epoch 100 Batch 300 Loss 0.0963
# Epoch 100 Loss 0.101892
# Time taken for 1 epoch 71.82 sec

# %%
encoder.save_weights("encoder.h5")
decoder.save_weights("decoder.h5")

# %%
plt.plot(loss_plot)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.show()

# %% [markdown]
# ## Caption!
#
# * The evaluate function is similar to the training loop, except you don't use teacher forcing here. The input to the decoder at each time step is its previous predictions along with the hidden state and the encoder output.
# * Stop predicting when the model predicts the end token.
# * And store the attention weights for every time step.

# %%
def evaluate(image):
    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.reset_state(batch_size=1)

    temp_input = tf.expand_dims(load_image(image)[0], 0)
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0],
                                                 -1,
                                                 img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']], 0)
    result = []

    for i in range(max_length):
        predictions, hidden, attention_weights = decoder(dec_input,
                                                         features,
                                                         hidden)

        attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()

        predicted_id = tf.random.categorical(predictions, 1)[0][0].numpy()
        result.append(tokenizer.index_word[predicted_id])

        if tokenizer.index_word[predicted_id] == '<end>':
            return result, attention_plot

        dec_input = tf.expand_dims([predicted_id], 0)

    attention_plot = attention_plot[:len(result), :]
    return result, attention_plot

# %%
def plot_attention(image, result, attention_plot):
    temp_image = np.array(Image.open(image))

    fig = plt.figure(figsize=(10, 10))

    len_result = len(result)
    for i in range(len_result):
        temp_att = np.resize(attention_plot[i], (8, 8))
        grid_size = max(np.ceil(len_result/2), 2)
        ax = fig.add_subplot(grid_size, grid_size, i+1)
        ax.set_title(result[i])
        img = ax.imshow(temp_image)
        ax.imshow(temp_att, cmap='gray', alpha=0.6, extent=img.get_extent())

    plt.tight_layout()
    plt.show()

# %%
# captions on the validation set
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tokenizer.index_word[i]
                        for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)

print('Real Caption:', real_caption)
print('Prediction Caption:', ' '.join(result))
plot_attention(image, result, attention_plot)
# Out:
# Real Caption: <start> a woman standing next to a car with a cat inside <end>
# Prediction Caption: a black while the red <unk> of a roll of a man <end>

# %% [markdown]
# ## Try it on your own images
# For fun, below we've provided a method you can use to caption your own images with the model we've just trained. Keep in mind, it was trained on a relatively small amount of data, and your images may be different from the training data (so be prepared for weird results!)

# %%
image_url = 'https://homepages.cae.wisc.edu/~ece533/images/airplane.png'
image_extension = image_url[-4:]
image_path = tf.keras.utils.get_file('image'+image_extension, origin=image_url)

result, attention_plot = evaluate(image_path)
print('Prediction Caption:', ' '.join(result))
plot_attention(image_path, result, attention_plot)
# opening the image
Image.open(image_path)
# Out:
# Prediction Caption: a blue airplane is going down a large snow <end>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7F042944DCD0>

# %%
# !zip -r /content/file.zip /content/checkpoints
# Out:
#   adding: content/checkpoints/ (stored 0%)
#   adding: content/checkpoints/train/ (stored 0%)
#   adding: content/checkpoints/train/checkpoint (deflated 54%)
#   adding: content/checkpoints/train/ckpt-1.data-00000-of-00001 (deflated 14%)
#   adding: content/checkpoints/train/ckpt-2.index (deflated 69%)
#   adding: content/checkpoints/train/ckpt-2.data-00000-of-00001 (deflated 14%)
#   adding: content/checkpoints/train/ckpt-1.index (deflated 69%)
